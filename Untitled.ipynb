# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf
# %matplotlib inline

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

# %%
# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename


filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# %%
# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)

# %%
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    random.shuffle(context_words)
    words_to_use = collections.deque(context_words)
    for j in range(num_skips):
      batch[i * num_skips + j] = buffer[skip_window]
      context_word = words_to_use.pop()
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3084 originated -> 12 as
# 3084 originated -> 5239 anarchism
# 12 as -> 6 a
# 12 as -> 3084 originated
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %%
graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  308.562255859
# Nearest to been: endoplasmic, isaac, hildebrand, loi, assassinations, pantheist, realization, incident,
# Nearest to in: bebe, incredible, differ, cardiology, unknown, hum, antagonists, keralite,
# Nearest to at: sprache, taklamakan, budgets, yakovlev, compassionate, guan, smuts, influence,
# Nearest to so: alpacas, cameroons, ddot, lockheed, worm, correlate, agnosticism, pounder,
# Nearest to most: longbowmen, rheingold, jinshi, interglacial, postseason, community, vse, bathe,
# Nearest to were: synonym, chilli, battista, gobi, plucked, amines, romeo, recovering,
# Nearest to which: regi, runyon, compresses, somatic, subtracting, respective, boc, monocots,
# Nearest to all: bonuses, ih, talkin, ethelred, furnace, tropics, pennsylvania, nassau,
# Nearest to between: tique, battlecruiser, feuding, kripke, baryons, notebook, cultic, distances,
# Nearest to not: kazakh, btu, basslines, induced, gallop, fluoride, insensitive, poe,
# Nearest to first: mediaeval, capitalisation, puns, isfahan, forcible, corresponds, liberties, possessing,
# Nearest to eight: arbitral, turbo, changed, serialism, cabo, arsenal, burbank, quito,
# Nearest to after: ports, gallium, corcovado, complimentary, kanji, cockroach, telangana, ekam,
# Nearest to six: hive, thunderstorms, airborne, tilted, mobilizing, noether, scheming, americanized,
# Nearest to for: mcbeal, sharps, michel, impaired, instruments, wagner, indulgences, revolted,
# Nearest to of: petrol, screening, paucity, hearses, joy, violinist, doolittle, celestines,
# Average loss at step  2000 :  113.63767511
# Average loss at step  4000 :  52.9390407777
# Average loss at step  6000 :  33.3527840075
# Average loss at step  8000 :  23.4486126277
# Average loss at step  10000 :  17.6971308178
# Nearest to been: isaac, incident, voltage, social, mhz, removal, bowl, zermelo,
# Nearest to in: and, of, at, tar, on, for, by, as,
# Nearest to at: in, and, of, predecessors, tar, to, jew, lighthouse,
# Nearest to so: boroughs, agnosticism, nine, tight, fallacy, ranks, behavior, popular,
# Nearest to most: universities, phi, officially, affidavit, community, justification, denmark, arguments,
# Nearest to were: are, is, biodiesel, and, heinlein, chapter, synonym, hudson,
# Nearest to which: and, agave, respective, android, planned, goya, phi, peril,
# Nearest to all: fao, alumni, nutrition, coast, section, sometimes, serve, wrongly,
# Nearest to between: all, patagonia, zero, overwhelming, astatine, community, archie, crusades,
# Nearest to not: induced, coke, message, achieved, pope, eukaryotic, even, also,
# Nearest to first: isfahan, contains, forcible, dispelling, mosque, services, ministers, equivalent,
# Nearest to eight: nine, zero, archie, vocals, agave, six, one, gb,
# Nearest to after: ports, nine, fund, attached, looters, quantities, amplitude, traditions,
# Nearest to six: zero, archie, nine, eight, coke, one, agave, two,
# Nearest to for: in, of, and, status, to, from, as, ranching,
# Nearest to of: and, in, for, kubitzki, nine, at, on, solf,
# Average loss at step  12000 :  14.1868101991
# Average loss at step  14000 :  11.652326247
# Average loss at step  16000 :  9.99323123801
# Average loss at step  18000 :  8.44985285044
# Average loss at step  20000 :  7.98048875773
# Nearest to been: isaac, was, is, by, be, girardeau, incident, voltage,
# Nearest to in: and, on, of, at, for, operatorname, from, with,
# Nearest to at: in, and, agouti, of, tar, predecessors, on, for,
# Nearest to so: albertus, alpacas, boroughs, agnosticism, dasyprocta, lockheed, fallacy, curtailed,
# Nearest to most: perceive, phi, officially, justification, agouti, universities, dasyprocta, affidavit,
# Nearest to were: are, was, is, and, he, had, biodiesel, unknown,
# Nearest to which: and, this, mlb, dasyprocta, agave, acacia, it, fronted,
# Nearest to all: fao, nutrition, alumni, negation, coast, wrongly, plausible, envision,
# Nearest to between: in, with, at, overwhelming, and, patagonia, acapulco, zero,
# Nearest to not: it, induced, coke, also, achieved, message, antoninus, even,
# Nearest to first: by, and, isfahan, sweetened, masses, forcible, methodist, operatorname,
# Nearest to eight: nine, six, zero, seven, four, five, three, two,
# Nearest to after: with, ports, agouti, for, and, looters, circ, quantities,
# Nearest to six: nine, eight, zero, four, three, two, five, dasyprocta,
# Nearest to for: in, of, and, from, agouti, as, by, circ,
# Nearest to of: and, in, for, operatorname, on, nine, from, agouti,
# Average loss at step  22000 :  7.02761890614
# Average loss at step  24000 :  6.8237901845
# Average loss at step  26000 :  6.69074787331
# Average loss at step  28000 :  6.38312669587
# Average loss at step  30000 :  5.93579348719
# Nearest to been: be, was, isaac, by, is, girardeau, incident, voltage,
# Nearest to in: at, on, and, operatorname, from, for, of, with,
# Nearest to at: in, agouti, on, tar, between, predecessors, for, and,
# Nearest to so: albertus, alpacas, agnosticism, boroughs, lockheed, ast, curtailed, dasyprocta,
# Nearest to most: postseason, perceive, very, justification, adventist, phi, administrative, dasyprocta,
# Nearest to were: are, was, is, had, by, have, when, and,
# Nearest to which: this, that, and, it, dasyprocta, agave, mlb, acacia,
# Nearest to all: fao, nutrition, alumni, wrongly, plausible, envision, coast, morita,
# Nearest to between: with, in, at, sponsors, overwhelming, patagonia, after, acapulco,
# Nearest to not: it, also, coke, to, induced, even, achieved, message,
# Nearest to first: amalthea, by, operatorname, forcible, sunk, handler, isfahan, masses,
# Nearest to eight: nine, seven, five, six, four, zero, three, two,
# Nearest to after: with, in, agouti, for, at, ports, looters, circ,
# Nearest to six: eight, nine, four, five, three, zero, seven, two,
# Nearest to for: and, in, of, from, by, agouti, with, sponsors,
# Nearest to of: and, in, for, operatorname, nine, eight, from, on,
# Average loss at step  32000 :  5.95509232354
# Average loss at step  34000 :  5.72751006293
# Average loss at step  36000 :  5.79028951776
# Average loss at step  38000 :  5.51228175354
# Average loss at step  40000 :  5.28595426691
# Nearest to been: be, was, isaac, by, had, girardeau, is, incident,
# Nearest to in: on, at, operatorname, and, from, during, zero, between,
# Nearest to at: in, on, agouti, between, predecessors, for, tar, and,
# Nearest to so: albertus, alpacas, boroughs, agnosticism, ast, only, dasyprocta, lockheed,
# Nearest to most: goo, postseason, perceive, more, qos, administrative, adventist, justification,
# Nearest to were: are, was, is, have, had, zero, be, being,
# Nearest to which: that, this, and, it, dasyprocta, also, agave, one,
# Nearest to all: fao, these, aveiro, nutrition, recitative, alumni, plausible, many,
# Nearest to between: with, in, at, sponsors, after, overwhelming, acapulco, notebook,
# Nearest to not: it, also, coke, to, achieved, induced, even, antoninus,
# Nearest to first: second, handler, operatorname, amalthea, isfahan, sweetened, forcible, by,
# Nearest to eight: nine, seven, six, zero, five, four, three, two,
# Nearest to after: in, agouti, with, between, at, looters, circ, lender,
# Nearest to six: eight, four, five, three, seven, zero, nine, two,
# Nearest to for: in, from, of, agouti, circ, and, zero, sponsors,
# Nearest to of: zero, and, in, operatorname, nine, for, agouti, circ,
# Average loss at step  42000 :  5.37081599224
# Average loss at step  44000 :  5.24372404122
# Average loss at step  46000 :  5.2102120707
# Average loss at step  48000 :  5.25160409522
# Average loss at step  50000 :  4.98174942088
# Nearest to been: be, was, isaac, by, had, girardeau, also, recounted,
# Nearest to in: at, on, operatorname, of, from, during, for, between,
# Nearest to at: in, on, agouti, three, between, and, during, one,
# Nearest to so: albertus, alpacas, ast, agnosticism, dasyprocta, boroughs, sizing, only,
# Nearest to most: more, postseason, goo, rheingold, perceive, administrative, qos, very,
# Nearest to were: are, was, is, had, have, nosferatu, abet, be,
# Nearest to which: this, that, and, also, it, one, solicitation, dasyprocta,
# Nearest to all: these, fao, recitative, nutrition, aveiro, many, four, alumni,
# Nearest to between: with, in, at, three, sponsors, overwhelming, kapoor, acapulco,
# Nearest to not: it, also, coke, to, even, eukaryotic, achieved, induced,
# Nearest to first: second, handler, amalthea, masses, operatorname, sweetened, babe, by,
# Nearest to eight: six, seven, nine, five, four, three, zero, two,
# Nearest to after: agouti, in, before, with, for, three, at, looters,
# Nearest to six: eight, four, five, seven, three, nine, zero, two,
# Nearest to for: in, agouti, circ, three, of, vma, and, sponsors,
# Nearest to of: in, operatorname, for, agouti, nine, circ, eight, amalthea,
# Average loss at step  52000 :  5.06596021307
# Average loss at step  54000 :  5.17376200759
# Average loss at step  56000 :  5.04387838197
# Average loss at step  58000 :  5.05497943473
# Average loss at step  60000 :  4.95045353782
# Nearest to been: be, was, by, had, michelob, isaac, become, girardeau,
# Nearest to in: at, on, operatorname, and, during, from, between, ursus,
# Nearest to at: in, on, agouti, three, during, five, for, kapoor,
# Nearest to so: albertus, alpacas, pulau, dasyprocta, agnosticism, ursus, ast, sizing,
# Nearest to most: more, postseason, goo, many, rheingold, perceive, administrative, some,
# Nearest to were: are, was, have, had, is, nosferatu, be, being,
# Nearest to which: that, this, it, also, one, ursus, solicitation, and,
# Nearest to all: these, three, fao, nutrition, many, two, recitative, aveiro,
# Nearest to between: with, in, at, from, overwhelming, sponsors, after, kapoor,
# Nearest to not: it, also, to, they, widely, coke, still, even,
# Nearest to first: second, amalthea, operatorname, handler, pulau, last, recitative, babe,
# Nearest to eight: nine, six, seven, five, four, three, zero, ursus,
# Nearest to after: before, agouti, during, when, in, at, six, where,
# Nearest to six: eight, five, four, seven, three, nine, zero, dasyprocta,
# Nearest to for: in, agouti, of, ursus, circ, vma, at, and,
# Nearest to of: and, in, ursus, for, operatorname, nine, six, circ,
# Average loss at step  62000 :  5.00209726954
# Average loss at step  64000 :  4.84405550748
# Average loss at step  66000 :  4.61068313861
# Average loss at step  68000 :  4.96490759361
# Average loss at step  70000 :  4.89578279364
# Nearest to been: be, was, had, become, by, michelob, were, never,
# Nearest to in: operatorname, at, during, thaler, and, cebus, on, ursus,
# Nearest to at: in, agouti, during, three, on, thaler, cebus, and,
# Nearest to so: albertus, alpacas, pulau, dasyprocta, ursus, sizing, ast, agnosticism,
# Nearest to most: more, postseason, many, goo, some, rheingold, perceive, administrative,
# Nearest to were: are, was, have, had, nosferatu, be, being, fills,
# Nearest to which: that, this, it, also, one, ursus, upanija, and,
# Nearest to all: these, many, three, upanija, recitative, aveiro, fao, nutrition,
# Nearest to between: with, in, from, at, overwhelming, notebook, sponsors, acapulco,
# Nearest to not: to, also, they, it, never, still, coke, you,
# Nearest to first: second, handler, last, only, amalthea, operatorname, babe, next,
# Nearest to eight: six, seven, nine, five, four, three, zero, two,
# Nearest to after: before, during, when, agouti, in, where, at, lender,
# Nearest to six: eight, five, four, seven, three, nine, two, zero,
# Nearest to for: circ, agouti, ursus, and, in, of, thaler, pulau,
# Nearest to of: operatorname, ursus, and, agouti, cebus, in, circ, for,
# Average loss at step  72000 :  4.76787791741
# Average loss at step  74000 :  4.81125837827
# Average loss at step  76000 :  4.72051054168
# Average loss at step  78000 :  4.80479544234
# Average loss at step  80000 :  4.77873829001
# Nearest to been: be, was, become, had, were, by, michelob, sociological,
# Nearest to in: operatorname, at, during, on, cebus, thaler, ursus, and,
# Nearest to at: in, on, during, five, agouti, thaler, cebus, three,
# Nearest to so: albertus, alpacas, pulau, dasyprocta, sizing, ursus, ast, pounder,
# Nearest to most: more, many, some, goo, postseason, administrative, very, adventist,
# Nearest to were: are, was, have, had, being, be, upanija, by,
# Nearest to which: this, that, it, also, ursus, upanija, but, microcebus,
# Nearest to all: these, many, upanija, recitative, two, aveiro, both, iit,
# Nearest to between: with, in, from, overwhelming, notebook, sponsors, kapoor, ursus,
# Nearest to not: it, never, also, they, to, still, you, widely,
# Nearest to first: second, last, next, handler, only, amalthea, refrained, operatorname,
# Nearest to eight: nine, six, seven, five, four, three, zero, dasyprocta,
# Nearest to after: before, during, when, agouti, in, lender, at, where,
# Nearest to six: five, seven, eight, four, three, nine, two, zero,
# Nearest to for: ursus, circ, agouti, of, thaler, pulau, and, mico,
# Nearest to of: operatorname, ursus, in, circ, cebus, nine, microcebus, agouti,
# Average loss at step  82000 :  4.77060531414
# Average loss at step  84000 :  4.76112900043
# Average loss at step  86000 :  4.75181075478
# Average loss at step  88000 :  4.74569980061
# Average loss at step  90000 :  4.73149468517
# Nearest to been: be, was, become, globemaster, had, by, were, sociological,
# Nearest to in: at, on, during, operatorname, thaler, cebus, from, ursus,
# Nearest to at: in, on, during, agouti, three, thaler, five, cebus,
# Nearest to so: albertus, alpacas, pulau, sizing, dasyprocta, ursus, globemaster, pounder,
# Nearest to most: more, many, some, postseason, goo, administrative, michelob, very,
# Nearest to were: are, was, have, had, being, be, by, upanija,
# Nearest to which: that, this, also, it, but, and, ursus, upanija,
# Nearest to all: these, many, both, upanija, some, recitative, two, aveiro,
# Nearest to between: with, in, overwhelming, from, notebook, into, sponsors, where,
# Nearest to not: they, never, it, you, still, also, to, antoninus,
# Nearest to first: second, last, only, next, handler, refrained, amalthea, operatorname,
# Nearest to eight: seven, nine, six, five, four, three, zero, dasyprocta,
# Nearest to after: before, during, when, agouti, while, in, lender, with,
# Nearest to six: seven, eight, five, four, three, nine, zero, two,
# Nearest to for: ursus, circ, agouti, thaler, in, and, kapoor, pulau,
# Nearest to of: ursus, cebus, operatorname, in, including, renfrew, microcebus, circ,
# Average loss at step  92000 :  4.68099614978
# Average loss at step  94000 :  4.72346720195
# Average loss at step  96000 :  4.68516941071
# Average loss at step  98000 :  4.59630878711
# Average loss at step  100000 :  4.70702904427
# Nearest to been: be, was, become, globemaster, had, by, sociological, were,
# Nearest to in: during, at, on, operatorname, thaler, from, within, cebus,
# Nearest to at: in, during, on, agouti, thaler, cebus, with, after,
# Nearest to so: albertus, alpacas, dasyprocta, pulau, sizing, globemaster, ursus, pounder,
# Nearest to most: more, many, some, goo, administrative, postseason, michelob, dictionary,
# Nearest to were: are, have, was, had, being, be, is, upanija,
# Nearest to which: that, this, also, it, but, and, what, ursus,
# Nearest to all: these, many, some, both, those, recitative, upanija, aces,
# Nearest to between: with, in, overwhelming, from, notebook, mojo, into, sponsors,
# Nearest to not: never, they, still, you, also, it, to, antoninus,
# Nearest to first: second, last, next, only, refrained, handler, operatorname, cheaply,
# Nearest to eight: seven, nine, five, six, four, three, zero, two,
# Nearest to after: before, during, when, agouti, while, in, with, at,
# Nearest to six: seven, eight, five, four, three, nine, two, dasyprocta,
# Nearest to for: circ, agouti, ursus, thaler, kapoor, pulau, cebus, in,
# Nearest to of: ursus, operatorname, circ, in, eight, agouti, cebus, microcebus,

# %%
final_embeddings
# Out:
# array([[-0.00874334, -0.03177729,  0.0854532 , ..., -0.08189446,
#         -0.04621461,  0.14931625],
#        [-0.13083757,  0.00907723,  0.0589231 , ...,  0.03583294,
#         -0.09396306,  0.07859871],
#        [-0.18262093, -0.01327248, -0.10663337, ...,  0.04578489,
#         -0.0441847 ,  0.04805673],
#        ...,
#        [-0.10605723,  0.00739472,  0.03817269, ...,  0.0777752 ,
#          0.09992364,  0.06888535],
#        [-0.13257185,  0.07284164, -0.14078645, ..., -0.12831941,
#          0.10374136,  0.10353105],
#        [-0.13685794, -0.06072231, -0.01403886, ...,  0.01712784,
#          0.01008233,  0.14871417]], dtype=float32)

# %%
# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

# %%
try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
