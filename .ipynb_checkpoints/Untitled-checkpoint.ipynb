# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

# %%
# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename


filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# %%
# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)

# %%
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    random.shuffle(context_words)
    words_to_use = collections.deque(context_words)
    for j in range(num_skips):
      batch[i * num_skips + j] = buffer[skip_window]
      context_word = words_to_use.pop()
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3084 originated -> 12 as
# 3084 originated -> 5239 anarchism
# 12 as -> 6 a
# 12 as -> 3084 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %%
graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  286.160491943
# Nearest to used: pineal, xiith, romita, emitted, arya, resonances, wellesley, stun,
# Nearest to over: fermions, picking, primer, undisclosed, attainment, greg, whip, reproduced,
# Nearest to years: basquiat, nitrates, piezoelectric, right, liars, bailiwicks, artemisia, detached,
# Nearest to time: accede, sima, fantastic, illyria, eucalyptus, iers, memorize, prima,
# Nearest to first: misgivings, stds, chi, transmitter, diminution, widget, resentful, glastonbury,
# Nearest to system: homerun, uriah, communicative, wap, augmented, habermas, upheaval, bulgakov,
# Nearest to however: ipo, zoo, hoist, freestyle, caspian, renoir, saves, basins,
# Nearest to or: gilliam, aspirations, hopeless, fingerprint, loki, folk, php, pegged,
# Nearest to one: within, opal, bok, spanned, gleason, collage, napoleonic, deciding,
# Nearest to their: offerings, craftsman, replenish, turpentine, coru, encirclement, kilometer, gao,
# Nearest to not: strenuously, competencies, diameter, concurrent, judeo, morpheus, veganism, applescript,
# Nearest to other: evocative, empedocles, opium, caspase, wednesday, bahnhof, rhyme, imbued,
# Nearest to his: cecil, endanger, afro, abolitionist, tenderness, jah, williamson, cid,
# Nearest to been: elliot, foy, sidemen, ignored, bulb, eastwards, fiorentina, firebird,
# Nearest to there: bcl, neues, erythematosus, legalised, nea, aiding, accurate, scheldt,
# Nearest to often: nilsson, evaluating, yehuda, fulfilling, striping, beatified, troughs, pips,
# Average loss at step  2000 :  113.992696256
# Average loss at step  4000 :  52.6431934493
# Average loss at step  6000 :  32.9970711949
# Average loss at step  8000 :  23.5191159663
# Average loss at step  10000 :  17.8278863263
# Nearest to used: austin, institute, romita, rest, how, agave, whether, vs,
# Nearest to over: backlit, various, primer, dependency, parity, four, qutb, kournikova,
# Nearest to years: right, zero, jpg, bckgr, explosion, basquiat, presence, college,
# Nearest to time: unarable, illyria, rudolph, drinking, means, sky, mostly, designated,
# Nearest to first: transmitter, selectively, message, reveals, chi, brewed, organization, yerushalmi,
# Nearest to system: issued, balloons, substitute, sub, apollo, b, augmented, directed,
# Nearest to however: basins, ipo, gland, zoo, out, caspian, angles, starting,
# Nearest to or: and, when, dddddd, deal, UNK, folk, printed, of,
# Nearest to one: two, zero, UNK, nine, bckgr, archie, cc, three,
# Nearest to their: the, offerings, engineering, equilibrium, rudolph, division, higher, archie,
# Nearest to not: ma, concurrent, alchemists, warm, stig, cracking, dynasties, that,
# Nearest to other: rhyme, tissue, and, termination, professor, opium, UNK, organisms,
# Nearest to his: the, vaccine, cecil, takeoff, profess, november, studies, confused,
# Nearest to been: bulb, you, angles, hid, animation, erik, define, euro,
# Nearest to there: it, they, engage, vs, accurate, most, beneficial, tax,
# Nearest to often: australians, specific, architecture, island, fulfilling, economy, whales, terrible,
# Average loss at step  12000 :  14.1637735584
# Average loss at step  14000 :  11.8029389448
# Average loss at step  16000 :  10.2097552578
# Average loss at step  18000 :  8.41470744061
# Average loss at step  20000 :  7.94890915334
# Nearest to used: austin, emitted, institute, romita, teachers, edwards, ammonite, how,
# Nearest to over: attainment, wattle, fermions, backlit, madeira, before, primer, four,
# Nearest to years: five, wattle, detached, zero, right, jpg, explosion, colin,
# Nearest to time: agouti, illyria, iers, unarable, rudolph, fantastic, mostly, drinking,
# Nearest to first: selectively, transmitter, operatorname, message, of, onyx, reveals, in,
# Nearest to system: agouti, julio, issued, balloons, pressed, duo, prof, augmented,
# Nearest to however: and, ipo, angles, basins, zoo, gland, yang, astoria,
# Nearest to or: and, the, UNK, three, agouti, dddddd, zero, operatorname,
# Nearest to one: two, seven, eight, six, three, agouti, nine, operatorname,
# Nearest to their: the, its, his, asgard, offerings, engineering, circ, a,
# Nearest to not: to, ma, that, alchemists, concurrent, operatorname, powder, stig,
# Nearest to other: rhyme, termination, tissue, commentaries, antoninus, professor, distraction, opium,
# Nearest to his: the, circ, her, its, kilda, and, s, their,
# Nearest to been: by, was, bulb, is, angles, you, be, to,
# Nearest to there: it, they, he, and, operatorname, circ, chapman, beneficial,
# Nearest to often: circ, architecture, australians, fulfilling, terrible, specific, phosphoric, whales,
# Average loss at step  22000 :  7.01215025878
# Average loss at step  24000 :  6.79734434831
# Average loss at step  26000 :  6.77194091451
# Average loss at step  28000 :  6.31571154118
# Average loss at step  30000 :  5.96779013777
# Nearest to used: emitted, romita, institute, edwards, teachers, handling, ammonite, dynamism,
# Nearest to over: attainment, billed, before, wattle, madeira, parity, fermions, four,
# Nearest to years: five, mishnayot, detached, nitrates, four, wattle, right, six,
# Nearest to time: agouti, iers, illyria, eucalyptus, abakan, fantastic, arrested, mostly,
# Nearest to first: selectively, transmitter, operatorname, dasyprocta, diminution, yerushalmi, difranco, message,
# Nearest to system: agouti, julio, prof, duo, issued, upheaval, pressed, augmented,
# Nearest to however: angles, abet, abakan, depict, ipo, that, zoo, but,
# Nearest to or: and, operatorname, agouti, dddddd, zero, hbox, six, circ,
# Nearest to one: two, seven, four, eight, three, agouti, operatorname, six,
# Nearest to their: the, its, his, asgard, a, several, some, circ,
# Nearest to not: to, it, abiogenesis, alchemists, ma, never, concurrent, powder,
# Nearest to other: caspase, rhyme, termination, distraction, commentaries, antoninus, opium, tissue,
# Nearest to his: the, their, her, its, s, circ, kilda, ducas,
# Nearest to been: by, was, be, bulb, you, tenses, angles, euro,
# Nearest to there: it, they, bcl, he, and, which, chapman, circ,
# Nearest to often: fulfilling, also, circ, terrible, architecture, australians, specific, special,
# Average loss at step  32000 :  5.95613701797
# Average loss at step  34000 :  5.66090731657
# Average loss at step  36000 :  5.77540444803
# Average loss at step  38000 :  5.49806032169
# Average loss at step  40000 :  5.25114939475
# Nearest to used: romita, emitted, institute, edwards, known, reductions, handling, teachers,
# Nearest to over: attainment, billed, four, before, parity, upu, wattle, primer,
# Nearest to years: five, mishnayot, four, detached, inequalities, wattle, nitrates, benzodiazepines,
# Nearest to time: agouti, iers, eucalyptus, fantastic, abakan, making, recitative, mostly,
# Nearest to first: transmitter, selectively, zero, difranco, operatorname, last, diminution, haight,
# Nearest to system: prof, duo, julio, agouti, augmented, upheaval, network, issued,
# Nearest to however: zero, but, freestyle, that, angles, abet, depict, abakan,
# Nearest to or: and, zero, dddddd, operatorname, agouti, eight, hbox, circ,
# Nearest to one: two, six, four, eight, three, seven, zero, five,
# Nearest to their: the, its, his, some, asgard, several, kifl, circ,
# Nearest to not: it, zero, to, never, they, abiogenesis, alchemists, stig,
# Nearest to other: rhyme, termination, caspase, distraction, these, zero, antoninus, identification,
# Nearest to his: their, the, its, her, s, circ, kilda, kifl,
# Nearest to been: be, was, by, had, bulb, tenses, you, become,
# Nearest to there: it, they, he, bcl, which, zero, and, now,
# Nearest to often: also, fulfilling, circ, terrible, usually, australians, not, marshes,
# Average loss at step  42000 :  5.39157052088
# Average loss at step  44000 :  5.26150177693
# Average loss at step  46000 :  5.23937879169
# Average loss at step  48000 :  5.21065836835
# Average loss at step  50000 :  4.97173417199
# Nearest to used: romita, known, emitted, edwards, institute, reductions, handling, teachers,
# Nearest to over: attainment, four, before, billed, three, wattle, parity, all,
# Nearest to years: piezoelectric, four, six, mishnayot, inequalities, five, detached, benzodiazepines,
# Nearest to time: mukherjee, agouti, making, iers, mostly, improvements, abakan, illyria,
# Nearest to first: last, transmitter, difranco, selectively, operatorname, diminution, widget, haight,
# Nearest to system: upheaval, julio, prof, augmented, duo, network, agouti, homerun,
# Nearest to however: but, and, freestyle, that, abakan, abet, four, depict,
# Nearest to or: and, dddddd, eight, operatorname, four, five, agouti, marek,
# Nearest to one: two, six, four, eight, three, seven, five, agouti,
# Nearest to their: his, its, the, her, some, asgard, kifl, several,
# Nearest to not: it, to, never, they, also, often, abiogenesis, operatorname,
# Nearest to other: rhyme, distraction, these, caspase, termination, three, many, two,
# Nearest to his: their, her, the, its, s, kilda, takeoff, circ,
# Nearest to been: be, was, by, become, had, tenses, bulb, being,
# Nearest to there: it, they, he, bcl, which, also, now, clippings,
# Nearest to often: also, usually, fulfilling, circ, now, not, terrible, who,
# Average loss at step  52000 :  5.04918160689
# Average loss at step  54000 :  5.18508158064
# Average loss at step  56000 :  5.01460146713
# Average loss at step  58000 :  5.05776066518
# Average loss at step  60000 :  4.95416897249
# Nearest to used: romita, known, emitted, ursus, edwards, reductions, teachers, handling,
# Nearest to over: attainment, before, four, billed, through, wattle, six, five,
# Nearest to years: piezoelectric, four, six, inequalities, mishnayot, benzodiazepines, five, detached,
# Nearest to time: mukherjee, agouti, making, iers, means, arrested, improvements, mostly,
# Nearest to first: last, difranco, transmitter, operatorname, selectively, sms, diminution, cem,
# Nearest to system: upheaval, augmented, duo, julio, agouti, prof, network, balloons,
# Nearest to however: but, that, and, abakan, freestyle, before, abet, ursus,
# Nearest to or: and, ursus, operatorname, dddddd, wct, five, agouti, circ,
# Nearest to one: two, six, four, five, three, seven, ursus, eight,
# Nearest to their: its, his, the, michelob, her, some, kifl, asgard,
# Nearest to not: it, they, never, to, also, usually, be, often,
# Nearest to other: these, many, rhyme, distraction, michelob, three, different, termination,
# Nearest to his: their, her, its, the, s, kilda, roshan, circ,
# Nearest to been: be, was, by, become, had, being, tenses, bulb,
# Nearest to there: it, they, he, bcl, which, now, also, clippings,
# Nearest to often: also, usually, fulfilling, now, circ, not, it, who,
# Average loss at step  62000 :  5.01442089498
# Average loss at step  64000 :  4.83884700841
# Average loss at step  66000 :  4.58388606369
# Average loss at step  68000 :  4.98621598434
# Average loss at step  70000 :  4.88084745693
# Nearest to used: known, romita, ursus, reductions, emitted, edwards, paigc, operatorname,
# Nearest to over: before, attainment, through, four, billed, five, wattle, parity,
# Nearest to years: five, piezoelectric, hagbard, inequalities, mishnayot, six, benzodiazepines, four,
# Nearest to time: agouti, making, mukherjee, iers, means, arrested, way, abakan,
# Nearest to first: last, difranco, transmitter, operatorname, sms, selectively, diminution, yerushalmi,
# Nearest to system: upheaval, network, agouti, augmented, julio, thaler, balloons, gluons,
# Nearest to however: but, and, that, freestyle, abakan, microcebus, abet, before,
# Nearest to or: and, ursus, operatorname, marek, dddddd, wct, agouti, microcebus,
# Nearest to one: six, two, five, four, seven, three, ursus, eight,
# Nearest to their: its, his, the, her, michelob, some, kifl, asgard,
# Nearest to not: usually, they, it, also, never, to, be, often,
# Nearest to other: many, these, different, some, michelob, distraction, rhyme, three,
# Nearest to his: their, her, its, the, cebus, kilda, s, roshan,
# Nearest to been: be, was, become, by, had, being, tenses, were,
# Nearest to there: it, they, he, bcl, which, now, still, also,
# Nearest to often: usually, also, now, fulfilling, generally, not, sometimes, circ,
# Average loss at step  72000 :  4.75676001251
# Average loss at step  74000 :  4.8124541775
# Average loss at step  76000 :  4.70931531322
# Average loss at step  78000 :  4.79246332872
# Average loss at step  80000 :  4.79929690707
# Nearest to used: known, romita, ursus, reductions, edwards, emitted, terminus, paigc,
# Nearest to over: before, through, attainment, billed, tonnage, parity, six, upanija,
# Nearest to years: piezoelectric, inequalities, hagbard, five, mishnayot, pontificia, benzodiazepines, four,
# Nearest to time: agouti, mukherjee, means, making, sibley, arrested, iers, way,
# Nearest to first: last, difranco, transmitter, sms, operatorname, diminution, cem, second,
# Nearest to system: upheaval, julio, network, augmented, agouti, gluons, thaler, balloons,
# Nearest to however: but, that, abakan, microcebus, abet, freestyle, and, ursus,
# Nearest to or: and, operatorname, ursus, marek, dddddd, agouti, dasyprocta, wct,
# Nearest to one: seven, six, two, five, four, ursus, three, callithrix,
# Nearest to their: its, his, the, her, michelob, some, kifl, our,
# Nearest to not: usually, it, they, never, also, often, still, to,
# Nearest to other: many, different, these, some, michelob, distraction, obtaining, rhyme,
# Nearest to his: their, her, its, the, s, cebus, kilda, vaccine,
# Nearest to been: be, was, become, by, had, being, were, tenses,
# Nearest to there: it, they, he, bcl, which, now, still, often,
# Nearest to often: usually, also, now, sometimes, generally, commonly, which, not,
# Average loss at step  82000 :  4.76378814828
# Average loss at step  84000 :  4.7581049192
# Average loss at step  86000 :  4.77523517418
# Average loss at step  88000 :  4.73023877013
# Average loss at step  90000 :  4.74852453327
# Nearest to used: known, romita, ursus, found, reductions, called, possible, cebus,
# Nearest to over: before, through, attainment, billed, when, avowed, within, whirlpool,
# Nearest to years: piezoelectric, inequalities, hagbard, five, pontificia, mishnayot, benzodiazepines, three,
# Nearest to time: means, mukherjee, guan, agouti, way, sibley, making, iers,
# Nearest to first: last, transmitter, difranco, sms, operatorname, second, diminution, pheasants,
# Nearest to system: julio, upheaval, network, agouti, thaler, gluons, augmented, habermas,
# Nearest to however: but, that, abet, microcebus, abakan, globemaster, while, freestyle,
# Nearest to or: and, six, ursus, operatorname, dddddd, marek, dasyprocta, wct,
# Nearest to one: two, four, three, seven, five, eight, six, callithrix,
# Nearest to their: its, his, the, her, michelob, some, kifl, our,
# Nearest to not: usually, they, it, never, often, also, still, to,
# Nearest to other: many, different, some, these, michelob, including, obtaining, two,
# Nearest to his: their, her, its, the, s, cebus, kilda, our,
# Nearest to been: be, was, become, had, by, being, were, tenses,
# Nearest to there: it, they, he, bcl, which, still, now, often,
# Nearest to often: usually, also, now, sometimes, generally, commonly, not, it,
# Average loss at step  92000 :  4.68324506378
# Average loss at step  94000 :  4.71891227424
# Average loss at step  96000 :  4.67452307332
# Average loss at step  98000 :  4.59678101063
# Average loss at step  100000 :  4.69712575686
# Nearest to used: known, romita, ursus, found, called, defined, possible, available,
# Nearest to over: before, through, attainment, billed, avowed, babylonians, tonnage, five,
# Nearest to years: inequalities, piezoelectric, five, hagbard, mishnayot, pontificia, benzodiazepines, months,
# Nearest to time: agouti, means, way, mukherjee, guan, sibley, operatorname, year,
# Nearest to first: last, second, sms, transmitter, difranco, operatorname, pheasants, diminution,
# Nearest to system: julio, network, agouti, thaler, habermas, upheaval, gluons, balloons,
# Nearest to however: but, that, while, abet, abakan, microcebus, globemaster, which,
# Nearest to or: and, ursus, marek, but, dddddd, dasyprocta, stenella, operatorname,
# Nearest to one: two, seven, six, four, five, three, eight, ursus,
# Nearest to their: its, his, the, her, michelob, some, kifl, our,
# Nearest to not: usually, they, never, also, still, often, it, to,
# Nearest to other: many, different, some, these, including, distraction, michelob, obtaining,
# Nearest to his: their, her, its, the, s, cebus, kilda, my,
# Nearest to been: be, become, was, being, had, by, were, already,
# Nearest to there: they, it, he, which, bcl, still, now, she,
# Nearest to often: usually, also, now, sometimes, generally, commonly, not, there,

# %%
final_embeddings
# Out:
# array([[-0.18111196, -0.06611396, -0.07250983, ...,  0.00443493,
#         -0.10709251, -0.04307367],
#        [ 0.00713664, -0.0767845 , -0.02049155, ...,  0.04436118,
#          0.02865021,  0.08066542],
#        [-0.14283094, -0.19753721, -0.03771205, ..., -0.11183577,
#          0.12594314, -0.15862554],
#        ...,
#        [-0.0300066 , -0.07592781, -0.05610738, ..., -0.01642986,
#          0.04683936,  0.04648537],
#        [-0.09891584, -0.04542745, -0.19851667, ..., -0.05211412,
#          0.09256292, -0.01382426],
#        [-0.06259994,  0.07106137, -0.0412217 , ..., -0.11494134,
#          0.16272604,  0.10212717]], dtype=float32)

# %%
# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)
